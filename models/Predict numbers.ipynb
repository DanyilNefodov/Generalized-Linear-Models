# %%
import numpy as np

# %%
np.random.seed(42)

n_samples, n_features = 300, 1
X = np.random.randn(n_samples, n_features)
print(X)
# Decreasing coef w. alternated signs for visualization
# W = np.array([1, -3, 6, 5, 4])
W = 1
w0 = 4
y = W * X  + w0

# # Add noise
y += 0.1*np.random.uniform(-1,1, size=[n_samples, n_features])
# Out:
# [[ 0.49671415]
#  [-0.1382643 ]
#  [ 0.64768854]
#  [ 1.52302986]
#  [-0.23415337]
#  [-0.23413696]
#  [ 1.57921282]
#  [ 0.76743473]
#  [-0.46947439]
#  [ 0.54256004]
#  [-0.46341769]
#  [-0.46572975]
#  [ 0.24196227]
#  [-1.91328024]
#  [-1.72491783]
#  [-0.56228753]
#  [-1.01283112]
#  [ 0.31424733]
#  [-0.90802408]
#  [-1.4123037 ]
#  [ 1.46564877]
#  [-0.2257763 ]
#  [ 0.0675282 ]
#  [-1.42474819]
#  [-0.54438272]
#  [ 0.11092259]
#  [-1.15099358]
#  [ 0.37569802]
#  [-0.60063869]
#  [-0.29169375]
#  [-0.60170661]
#  [ 1.85227818]
#  [-0.01349722]
#  [-1.05771093]
#  [ 0.82254491]
#  [-1.22084365]
#  [ 0.2088636 ]
#  [-1.95967012]
#  [-1.32818605]
#  [ 0.19686124]
#  [ 0.73846658]
#  [ 0.17136828]
#  [-0.11564828]
#  [-0.3011037 ]
#  [-1.47852199]
#  [-0.71984421]
#  [-0.46063877]
#  [ 1.05712223]
#  [ 0.34361829]
#  [-1.76304016]
#  [ 0.32408397]
#  [-0.38508228]
#  [-0.676922  ]
#  [ 0.61167629]
#  [ 1.03099952]
#  [ 0.93128012]
#  [-0.83921752]
#  [-0.30921238]
# ...

# %%
from sklearn.datasets import make_regression

X, y = make_regression(n_samples=100, n_features=1, 
                       n_informative=10, n_targets=1, 
                       bias=0.0, tail_strength=0.5, 
                       noise=3)
plt.scatter(X, y)

# %%
# Split data in train set and test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60, 1)
# (40, 1)
# (60,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = lin_model.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = lin_model.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 2.851340886683267
# R2 score is 0.9269381119216248
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 3.5811997726447866
# R2 score is 0.9232705718046434

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(normalize = True)
ridge.fit(X_train, y_train)

ridge_0 = Ridge(alpha = 0.001, normalize = True)
ridge_0.fit(X_train, y_train)

ridge_2 = Ridge(alpha = 2, normalize = True)
ridge_2.fit(X_train, y_train)

ridge_10__10 = Ridge(alpha = 10**10, normalize = True)
ridge_10__10.fit(X_train, y_train)
# Out:
# Ridge(alpha=10000000000, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=True, random_state=None, solver='auto', tol=0.001)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = ridge.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = ridge.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 5.823829126700233
# R2 score is 0.6952035839412184
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 7.988520864836814
# R2 score is 0.6181985152520832

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = ridge_0.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = ridge_0.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 2.854418827312087
# R2 score is 0.9965016541110492
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 3.3046754602225104
# R2 score is 0.9952293872053899

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = ridge_2.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = ridge_2.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 7.346660293308864
# R2 score is 0.5149656177342359
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 9.86931294510048
# R2 score is 0.4172547991068969

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = ridge_10__10.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = ridge_10__10.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 10.548815488535352
# R2 score is 1.8538737212026035e-10
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 13.764507055428632
# R2 score is -0.13351217892997091

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(max_iter = 10000, normalize = True)
lasso.fit(X_train, y_train)

lasso_0 = Lasso(max_iter = 10000, alpha = -10, normalize = True)
lasso_0.fit(X_train, y_train)

lasso_2 = Lasso(max_iter = 10000, alpha = 2, normalize = True)
lasso_2.fit(X_train, y_train)

lasso_10__10 = Lasso(max_iter = 10000, alpha = 10**10, normalize = True)
lasso_10__10.fit(X_train, y_train)
# Out:
# Lasso(alpha=10000000000, copy_X=True, fit_intercept=True, max_iter=10000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = lasso.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = lasso.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 8.254098669877393
# R2 score is 0.3877455926658997
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 10.978141730010222
# R2 score is 0.27895473062972087

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = lasso_0.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = lasso_0.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 77.51212901767097
# R2 score is -52.992313813650846
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 92.13838895495863
# R2 score is -49.790921685503534

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = lasso_2.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = lasso_2.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 10.54881548951316
# R2 score is 0.0
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 13.764507056612635
# R2 score is -0.13351217912497693

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = lasso_10__10.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = lasso_10__10.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 10.54881548951316
# R2 score is 0.0
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 13.764507056612635
# R2 score is -0.13351217912497693

# %%
from sklearn.linear_model import ElasticNet

enet = ElasticNet(l1_ratio=0.7)
enet.fit(X_train, y_train)

enet_0 = ElasticNet(alpha=0.001, l1_ratio=0.7)
enet_0.fit(X_train, y_train)

enet_2 = ElasticNet(alpha=2, l1_ratio=0.7)
enet_2.fit(X_train, y_train)

enet_10__10 = ElasticNet(alpha=10**10, l1_ratio=0.7)
enet_10__10.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=10000000000, copy_X=True, fit_intercept=True, l1_ratio=0.7,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = enet.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = enet.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 4.320061798562518
# R2 score is 0.8322847605059233
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 6.066671443767511
# R2 score is 0.7798058301976761

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = enet_0.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = enet_0.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 2.85134429460453
# R2 score is 0.9269379372744531
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 3.582859559602738
# R2 score is 0.9231994313908489

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = enet_2.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = enet_2.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 5.873398430518402
# R2 score is 0.68999297637256
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 8.050375224083345
# R2 score is 0.6122631199124058

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_predict = enet_10__10.predict(X_train)

rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

y_test_predict = enet_10__10.predict(X_test)

rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 10.54881548951316
# R2 score is 0.0
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 13.764507056612635
# R2 score is -0.13351217912497693
