# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train = pd.read_csv('cs-training.csv')
train.pop('Unnamed: 0')
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 149995    149996
# 149996    149997
# 149997    149998
# 149998    149999
# 149999    150000
# Name: Unnamed: 0, Length: 150000, dtype: int64

# %%
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# std                                4.192781    2037.818523   1.438467e+04
# min                                0.000000       0.000000   0.000000e+00
# 25%                                0.000000       0.175074   3.400000e+03
# 50%                                0.000000       0.366508   5.400000e+03
# 75%                                0.000000       0.868254   8.249000e+03
# max                               98.000000  329664.000000   3.008750e+06
#
#        NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# count                    150000.000000            150000.000000
# mean                          8.452760                 0.265973
# std                           5.145951                 4.169304
# min                           0.000000                 0.000000
# 25%                           5.000000                 0.000000
# 50%                           8.000000                 0.000000
# 75%                          11.000000                 0.000000
# max                          58.000000                98.000000
#
#        NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# count                 150000.000000                         150000.000000
# mean                       1.018240                              0.240387
# std                        1.129771                              4.155179
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        1.000000                              0.000000
# 75%                        2.000000                              0.000000
# max                       54.000000                             98.000000
#
#        NumberOfDependents
# count       146076.000000
# mean             0.757222
# std              1.115086
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max             20.000000

# %%
train.isna().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %% [markdown]
# ### So we can see that *MonthlyIncome* and *NumberOfDependents* have some missed values.

# %%
train.corr(method='spearman').style.background_gradient(cmap='seismic')
# Out:
# <style  type="text/css" >
#     #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col0 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col1 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col2 {
#             background-color:  #0000a6;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col3 {
#             background-color:  #4949ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col4 {
#             background-color:  #0000ac;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col5 {
#             background-color:  #000074;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col6 {
#             background-color:  #000087;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col7 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col8 {
#             background-color:  #000076;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col9 {
#             background-color:  #5555ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow0_col10 {
#             background-color:  #0000ec;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col0 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col1 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col2 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col3 {
#             background-color:  #3131ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col4 {
#             background-color:  #0000cd;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col5 {
#             background-color:  #00006b;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col6 {
#             background-color:  #000068;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col7 {
#             background-color:  #4d4dff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col8 {
#             background-color:  #00007c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col9 {
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow1_col10 {
#             background-color:  #2121ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col0 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col1 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col2 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col3 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col4 {
#             background-color:  #0000b1;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col5 {
#             background-color:  #0000f4;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col6 {
#             background-color:  #0909ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col7 {
#             background-color:  #00005d;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col8 {
#             background-color:  #0000b1;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col9 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow2_col10 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col0 {
#             background-color:  #5555ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col1 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col2 {
#             background-color:  #0000b1;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col3 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col4 {
#             background-color:  #0000b7;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col5 {
#             background-color:  #000095;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col6 {
#             background-color:  #0000c8;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col7 {
#             background-color:  #5d5dff;
#             color:  #000000;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col8 {
#             background-color:  #00009b;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col9 {
#             background-color:  #5959ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow3_col10 {
#             background-color:  #0000fa;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col0 {
#             background-color:  #0000a3;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col1 {
#             background-color:  #1d1dff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col2 {
#             background-color:  #0000f7;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col3 {
#             background-color:  #0000a3;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col4 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col5 {
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col6 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col7 {
#             background-color:  #00008d;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col8 {
#             background-color:  #d1d1ff;
#             color:  #000000;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col9 {
#             background-color:  #000084;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow4_col10 {
#             background-color:  #0000ba;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow5_col0 {
#             background-color:  #00006b;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow5_col1 {
#             background-color:  #0000bc;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow5_col2 {
#             background-color:  #4949ff;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow5_col3 {
#             background-color:  #00007f;
#             color:  #f1f1f1;
#         }    #T_25468ad8_0ec8_11ea_b99e_ebb4175b6cedrow5_col4 {
#             background-color:  #00004c;
#             color:  #f1f1f1

# %%
plt.rcParams.update({'font.size': 22})
fig, axes = plt.subplots(3, 3, figsize=(30,30))
for data, ax in zip(train[['age', 'NumberOfTimes90DaysLate', 'NumberOfTime60-89DaysPastDueNotWorse', 'MonthlyIncome', 'DebtRatio', 'NumberOfOpenCreditLinesAndLoans', 'NumberRealEstateLoansOrLines', 'RevolvingUtilizationOfUnsecuredLines', 'NumberOfDependents']], axes.flat):
    train.boxplot(data, ax=ax)

# %% [markdown]
# ## Lets check SeriousDlqin2yrs variable

# %%
train.loc[train.SeriousDlqin2yrs==1].count()
# Out:
# SeriousDlqin2yrs                        10026
# RevolvingUtilizationOfUnsecuredLines    10026
# age                                     10026
# NumberOfTime30-59DaysPastDueNotWorse    10026
# DebtRatio                               10026
# MonthlyIncome                            8357
# NumberOfOpenCreditLinesAndLoans         10026
# NumberOfTimes90DaysLate                 10026
# NumberRealEstateLoansOrLines            10026
# NumberOfTime60-89DaysPastDueNotWorse    10026
# NumberOfDependents                       9847
# dtype: int64

# %%
train.loc[train.SeriousDlqin2yrs==0].count()
# Out:
# SeriousDlqin2yrs                        139974
# RevolvingUtilizationOfUnsecuredLines    139974
# age                                     139974
# NumberOfTime30-59DaysPastDueNotWorse    139974
# DebtRatio                               139974
# MonthlyIncome                           111912
# NumberOfOpenCreditLinesAndLoans         139974
# NumberOfTimes90DaysLate                 139974
# NumberRealEstateLoansOrLines            139974
# NumberOfTime60-89DaysPastDueNotWorse    139974
# NumberOfDependents                      136229
# dtype: int64

# %% [raw]
# train.DebtRatio.describe()

# %%
train.DebtRatio.quantile(0.975)
# Out:
# 3489.024999999994

# %%
train[train['DebtRatio'] > 3489.025][['DebtRatio','MonthlyIncome']].describe()
# Out:
#            DebtRatio  MonthlyIncome
# count    3750.000000     185.000000
# mean     5917.488000       0.064865
# std     10925.524011       0.246956
# min      3490.000000       0.000000
# 25%      3957.250000       0.000000
# 50%      4619.000000       0.000000
# 75%      5789.500000       0.000000
# max    329664.000000       1.000000

# %%
train[(train['DebtRatio'] > 3489.025) & (train['SeriousDlqin2yrs'] == train['MonthlyIncome'])].shape[0]
# Out:
# 164

# %%
train.groupby('NumberOfTimes90DaysLate').NumberOfTimes90DaysLate.count()
# Out:
# NumberOfTimes90DaysLate
# 0     141662
# 1       5243
# 2       1555
# 3        667
# 4        291
# 5        131
# 6         80
# 7         38
# 8         21
# 9         19
# 10         8
# 11         5
# 12         2
# 13         4
# 14         2
# 15         2
# 17         1
# 96         5
# 98       264
# Name: NumberOfTimes90DaysLate, dtype: int64

# %%
train.groupby('NumberOfTime60-89DaysPastDueNotWorse')['NumberOfTime60-89DaysPastDueNotWorse'].count()
# Out:
# NumberOfTime60-89DaysPastDueNotWorse
# 0     142396
# 1       5731
# 2       1118
# 3        318
# 4        105
# 5         34
# 6         16
# 7          9
# 8          2
# 9          1
# 11         1
# 96         5
# 98       264
# Name: NumberOfTime60-89DaysPastDueNotWorse, dtype: int64

# %%
train.groupby('NumberOfTime30-59DaysPastDueNotWorse')['NumberOfTime30-59DaysPastDueNotWorse'].count()
# Out:
# NumberOfTime30-59DaysPastDueNotWorse
# 0     126018
# 1      16033
# 2       4598
# 3       1754
# 4        747
# 5        342
# 6        140
# 7         54
# 8         25
# 9         12
# 10         4
# 11         1
# 12         2
# 13         1
# 96         5
# 98       264
# Name: NumberOfTime30-59DaysPastDueNotWorse, dtype: int64

# %% [markdown]
# ### So there are 264 people who have a lot of days late

# %%
train[train['RevolvingUtilizationOfUnsecuredLines'] > 10].describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines         age  \
# count        241.000000                            241.000000  241.000000
# mean           0.070539                           3564.023932   50.630705
# std            0.256587                           5123.802683   14.565389
# min            0.000000                             11.385230   24.000000
# 25%            0.000000                            941.000000   39.000000
# 50%            0.000000                           2012.000000   48.000000
# 75%            0.000000                           4116.000000   62.000000
# max            1.000000                          50708.000000   87.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse     DebtRatio  MonthlyIncome  \
# count                            241.000000    241.000000      173.00000
# mean                               0.186722    571.918644     8467.67052
# std                                0.579502   1772.948412     6564.06825
# min                                0.000000      0.000800        0.00000
# 25%                                0.000000      0.217813     4500.00000
# 50%                                0.000000      0.402560     7000.00000
# 75%                                0.000000     59.000000    10091.00000
# max                                3.000000  21395.000000    44472.00000
#
#        NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# count                       241.000000               241.000000
# mean                          5.763485                 0.074689
# std                           3.114160                 0.579711
# min                           1.000000                 0.000000
# 25%                           4.000000                 0.000000
# 50%                           5.000000                 0.000000
# 75%                           7.000000                 0.000000
# max                          21.000000                 8.000000
#
#        NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# count                    241.000000                            241.000000
# mean                       1.186722                              0.087137
# std                        1.065750                              0.559651
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        1.000000                              0.000000
# 75%                        2.000000                              0.000000
# max                        9.000000                              7.000000
#
#        NumberOfDependents
# count          228.000000
# mean             0.688596
# std              1.038659
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              4.000000

# %%
removed_debt_outliers = train.drop(train[train['DebtRatio'] > 3489.025].index)
removed_debt_outliers = removed_debt_outliers.fillna(removed_debt_outliers.median())

# %%
removed_ruul = removed_debt_outliers.drop(removed_debt_outliers[removed_debt_outliers['RevolvingUtilizationOfUnsecuredLines'] > 10].index)

# %%
prepared = removed_ruul.copy()
prepared.loc[prepared['NumberOfTime30-59DaysPastDueNotWorse'] > 90, 'NumberOfTime30-59DaysPastDueNotWorse'] = 18
prepared.loc[prepared['NumberOfTime60-89DaysPastDueNotWorse'] > 90, 'NumberOfTime60-89DaysPastDueNotWorse'] = 18
prepared.loc[prepared['NumberOfTimes90DaysLate'] > 90, 'NumberOfTimes90DaysLate'] = 18

# %%
prepared.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     146021.000000                         146021.000000  146021.000000
# mean           0.066901                              0.322247      52.257059
# std            0.249852                              0.367259      14.862451
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029462      41.000000
# 50%            0.000000                              0.151559      52.000000
# 75%            0.000000                              0.555345      63.000000
# max            1.000000                              8.851852     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         146021.000000  146021.000000   1.460210e+05
# mean                               0.277214     210.204957   6.449414e+03
# std                                1.030522     620.319606   1.305969e+04
# min                                0.000000       0.000000   0.000000e+00
# 25%                                0.000000       0.169799   3.833000e+03
# 50%                                0.000000       0.355966   5.400000e+03
# 75%                                0.000000       0.757453   7.500000e+03
# max                               18.000000    3489.000000   3.008750e+06
#
#        NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# count                    146021.000000            146021.000000
# mean                          8.378035                 0.124414
# std                           5.116762                 0.909321
# min                           0.000000                 0.000000
# 25%                           5.000000                 0.000000
# 50%                           8.000000                 0.000000
# 75%                          11.000000                 0.000000
# max                          58.000000                18.000000
#
#        NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# count                 146021.000000                         146021.000000
# mean                       0.984886                              0.098095
# std                        1.099282                              0.836901
# min                        0.000000                              0.000000
# 25%                        0.000000                              0.000000
# 50%                        1.000000                              0.000000
# 75%                        2.000000                              0.000000
# max                       54.000000                             18.000000
#
#        NumberOfDependents
# count       146021.000000
# mean             0.742879
# std              1.108624
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max             20.000000

# %%
plt.rcParams.update({'font.size': 22})
fig, axes = plt.subplots(3, 3, figsize=(30,30))
for data, ax in zip(prepared[['age', 'NumberOfTimes90DaysLate', 'NumberOfTime60-89DaysPastDueNotWorse', 'MonthlyIncome', 'DebtRatio', 'NumberOfOpenCreditLinesAndLoans', 'NumberRealEstateLoansOrLines', 'RevolvingUtilizationOfUnsecuredLines', 'NumberOfDependents']], axes.flat):
    prepared.boxplot(data, ax=ax)
